# %% [markdown]
# <a href="https://colab.research.google.com/github/DinarSS/-/blob/main/%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BA%D0%B0%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2025-03-14 at 16.04.54.png](data:image/png;base64,...)

# %% [markdown]
# 1.

# %%
a=float(input('a'))
b=float(input('b'))
x=((a*b)/(a**2-b**2))-((b)/(2*a-3*b))
print(x)
# Out:
# a2
# b3
# -0.6

# %% [markdown]
# 2.

# %%
import math
a=float(input('a'))
b=float(input('b'))
z=2*x/math.cos(x)+3*x
print (z)
# Out:
# a5
# b4
# -3.2539539774147794

# %% [markdown]
# 3.

# %%
import math
R=float(input("0,6):"))
H=float(input("3,25):"))
V_cylinder=math.pi*R**2*H
V_cone=(1/3)*math.pi*R**2*H
print(f"0,6:{V_cylinder:.2f}")
print(f"3,25:{V_cone:.2f}")
# Out:
# 0,6):3
# 3,25):5
# 0,6:141.37
# 3,25:47.12

# %% [markdown]
# 4.

# %%
k=int(input("1):"))
day_of_week=(k+0)%7
week_days={0:"Воскресенье",1:"Понедельник",2:"Вторник",3:"Среда",4:"Четверг",5:"Пятница",6:"Суббота"}
print(f"Понедельник{k}")
# Out:
# 1):1
# Понедельник1

# %% [markdown]
# 5.

# %%
A=int(input("5:"))
B=int(input("3:"))
C=int(input("8:"))
all_positive=A>5 and B>3 and C>8
if all_positive:
  print("Высказывание ИСТИННО:все три числа положительные.")
else:
  print("Высказывыание ЛОЖНО:не все числа положительные.")
# Out:
# 5:6
# 3:4
# 8:9
# Высказывание ИСТИННО:все три числа положительные.
